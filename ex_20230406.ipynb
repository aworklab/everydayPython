# %% [markdown]
# <a href="https://colab.research.google.com/github/aworklab/everydayPython/blob/main/ex_20230406.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 오늘의 목표
# * Customer Analysis
# * Iterators

# %%
import pandas as pd
import numpy as np
import plotnine as gg
from plotnine import ggplot, aes
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, date, time, timezone, timedelta
import os
import re
from functools import reduce
from collections import defaultdict
from scipy import stats
from scipy.stats import norm

# %% [markdown]
# # Customer Analysis

# %%
os.listdir()
# Out:
# ['.config',
#  'scanner_data.csv',
#  'bz_data_analyis.csv',
#  'cookie_cats.csv',
#  'test.csv',
#  'sales_vs_discount.csv',
#  'app_wau.csv',
#  'sales_data_with_stores.csv',
#  'KPMG_VI_New_raw_data_update_final.xlsx',
#  'sales.csv',
#  'WA_Fn-UseC_-Telco-Customer-Churn.csv',
#  'mock_sales_data.csv',
#  'ecommerce-data.csv',
#  'groceries.csv',
#  'WA_Fn-UseC_-Marketing-Customer-Value-Analysis.csv',
#  'mall_customers.csv',
#  'match_result_test.csv',
#  'online_retail.xlsx',
#  'online_retail_II.xlsx',
#  'sample-sales-data.csv',
#  '1_orders_dataset.csv',
#  '1_customers_dataset.csv',
#  'ab_experiment.csv',
#  'lead_conversion.csv',
#  '1_order_payments_dataset.csv',
#  'KPMG_VI_New_raw_data_update_final.csv',
#  'sample_data']

# %%
df = pd.read_csv('ab_experiment.csv')
df.occurred_at = pd.to_datetime(df.occurred_at, format = '%Y-%m-%d %H:%M:%S')
df['hour'] = df.occurred_at.dt.hour
df.head()
# Out:
#    user_id         occurred_at  ... user_type hour
# 0      4.0 2014-06-05 15:20:16  ...       3.0   15
# 1   8198.0 2014-06-11 09:31:32  ...       1.0    9
# 2     11.0 2014-06-17 09:31:22  ...       1.0    9
# 3   8209.0 2014-06-04 09:31:21  ...       1.0    9
# 4     19.0 2014-06-04 09:31:33  ...       1.0    9
#
# [5 rows x 8 columns]

# %%
df[['experiment', 'experiment_group']].value_counts()
# Out:
# experiment        experiment_group
# publisher_update  control_group       1746
#                   test_group           849
# dtype: int64

# %%
sns.countplot(data = df, x = 'experiment_group', hue = 'location')
plt.legend(bbox_to_anchor = [1.01,1], ncol = 3)
plt.show()

# %%
cnt_test = df.groupby(['location', 'experiment_group'])['user_id'].count().reset_index(name = 'cnt')
cnt_test['ratio'] = cnt_test.groupby(['location'])['cnt'].apply(lambda x : round(x/sum(x)*100,2))
cnt_test.head()
# Out:
#     location experiment_group  cnt  ratio
# 0  Argentina    control_group   15  78.95
# 1  Argentina       test_group    4  21.05
# 2  Australia    control_group   30  57.69
# 3  Australia       test_group   22  42.31
# 4    Austria    control_group   11  64.71

# %%
plt.figure(figsize = [12,6])
sns.lineplot(data = cnt_test[cnt_test['experiment_group'] == 'control_group'], x = 'location', y = 'ratio')
plt.xticks(rotation = 90, ha = 'left')
plt.axhline(y = 0)
plt.axhline(y = 100)
plt.show()

# %% [markdown]
# # Iterators

# %%
users = [{'mail': 'gregorythomas@gmail.com', 'name': 'Brett Holland', 'sex': 'M', 'age': 73},
 {'mail': 'hintoncynthia@hotmail.com', 'name': 'Madison Martinez', 'sex': 'F', 'age': 29},
 {'mail': 'wwagner@gmail.com', 'name': 'Michael Jenkins', 'sex': 'M', 'age': 51},
 {'mail': 'daniel79@gmail.com', 'name': 'Karen Rodriguez', 'sex': 'F', 'age': 32},
 {'mail': 'ujackson@gmail.com', 'name': 'Amber Rhodes', 'sex': 'F', 'age': 42}]
users
# Out:
# [{'mail': 'gregorythomas@gmail.com',
#   'name': 'Brett Holland',
#   'sex': 'M',
#   'age': 73},
#  {'mail': 'hintoncynthia@hotmail.com',
#   'name': 'Madison Martinez',
#   'sex': 'F',
#   'age': 29},
#  {'mail': 'wwagner@gmail.com',
#   'name': 'Michael Jenkins',
#   'sex': 'M',
#   'age': 51},
#  {'mail': 'daniel79@gmail.com',
#   'name': 'Karen Rodriguez',
#   'sex': 'F',
#   'age': 32},
#  {'mail': 'ujackson@gmail.com', 'name': 'Amber Rhodes', 'sex': 'F', 'age': 42}]

# %%
{k : eval(f'reduce(lambda acc, cur : acc + [cur["{k}"]], users, [])') for k in users[0].keys()}
# Out:
# {'mail': ['gregorythomas@gmail.com',
#   'hintoncynthia@hotmail.com',
#   'wwagner@gmail.com',
#   'daniel79@gmail.com',
#   'ujackson@gmail.com'],
#  'name': ['Brett Holland',
#   'Madison Martinez',
#   'Michael Jenkins',
#   'Karen Rodriguez',
#   'Amber Rhodes'],
#  'sex': ['M', 'F', 'M', 'F', 'F'],
#  'age': [73, 29, 51, 32, 42]}

# %%
{k : [user[k] for user in users] for k in users[0].keys()}
# Out:
# {'mail': ['gregorythomas@gmail.com',
#   'hintoncynthia@hotmail.com',
#   'wwagner@gmail.com',
#   'daniel79@gmail.com',
#   'ujackson@gmail.com'],
#  'name': ['Brett Holland',
#   'Madison Martinez',
#   'Michael Jenkins',
#   'Karen Rodriguez',
#   'Amber Rhodes'],
#  'sex': ['M', 'F', 'M', 'F', 'F'],
#  'age': [73, 29, 51, 32, 42]}
