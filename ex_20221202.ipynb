# %% [markdown]
# <a href="https://colab.research.google.com/github/aworklab/everydayPython/blob/main/ex_20221202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 오늘의 목표
# * Customer Analysis
# * Iterators

# %%
import pandas as pd
import numpy as np
import plotnine as gg
from plotnine import ggplot, aes
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, date, time, timezone, timedelta 
import os
import re

from functools import reduce
from collections import defaultdict

import prophet as pr
import sklearn.datasets as skd

# %% [markdown]
# # Customer Analysis

# %%
os.listdir()
# Out:
# ['.config',
#  'sales_data_with_stores.csv',
#  '1_order_payments_dataset.csv',
#  'online_retail_II.xlsx',
#  'sales_vs_discount.csv',
#  'bz_data_analyis.csv',
#  'groceries.csv',
#  'mall_customers.csv',
#  'KPMG_VI_New_raw_data_update_final.csv',
#  'KPMG_VI_New_raw_data_update_final.xlsx',
#  'ecommerce-data.csv',
#  'sample-sales-data.csv',
#  'online_retail.xlsx',
#  '1_orders_dataset.csv',
#  'sales.csv',
#  'scanner_data.csv',
#  'match_result_test.csv',
#  '1_customers_dataset.csv',
#  'test.csv',
#  'mock_sales_data.csv',
#  'sample_data']

# %%
raw = skd.make_biclusters((1000, 5), 1)
x, y, z = raw[0], raw[1], raw[2]

# %%
print(x.shape, y.reshape(-1,1).shape, z.shape)
# Out:
# (1000, 5) (1000, 1) (1, 5)

# %%
df = pd.DataFrame(np.column_stack((x, y.reshape(-1,1))), columns = list('abcde') + ['y'])
df.drop_duplicates()
# Out:
#            a          b          c          d          e    y
# 0  68.440114  68.440114  68.440114  68.440114  68.440114  1.0

# %%
raw = skd.load_boston()
raw.keys()
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
# ...

# %%
# Out:
# ['CRIM',
#  'ZN',
#  'INDUS',
#  'CHAS',
#  'NOX',
#  'RM',
#  'AGE',
#  'DIS',
#  'RAD',
#  'TAX',
#  'PTRATIO',
#  'B',
#  'LSTAT',
#  'target']

# %%
df = pd.DataFrame(np.column_stack((raw['data'], raw['target'].reshape(-1,1))), columns = raw['feature_names'].tolist() + ['target'])
df.columns = [a.lower() for a in df.columns]
df.head()
# Out:
#       crim    zn  indus  chas    nox  ...    tax  ptratio       b  lstat  target
# 0  0.00632  18.0   2.31   0.0  0.538  ...  296.0     15.3  396.90   4.98    24.0
# 1  0.02731   0.0   7.07   0.0  0.469  ...  242.0     17.8  396.90   9.14    21.6
# 2  0.02729   0.0   7.07   0.0  0.469  ...  242.0     17.8  392.83   4.03    34.7
# 3  0.03237   0.0   2.18   0.0  0.458  ...  222.0     18.7  394.63   2.94    33.4
# 4  0.06905   0.0   2.18   0.0  0.458  ...  222.0     18.7  396.90   5.33    36.2
#
# [5 rows x 14 columns]

# %%
sns.histplot(data = df, x = 'target', bins = 35, kde = True)

# %%
from string import ascii_lowercase as lw

# %%
list(lw[0:10])
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
df['rate'] = pd.qcut(df['target'], 10, list('jihgfedcba'))
df.head()
# Out:
#       crim    zn  indus  chas    nox  ...  ptratio       b  lstat  target  rate
# 0  0.00632  18.0   2.31   0.0  0.538  ...     15.3  396.90   4.98    24.0     d
# 1  0.02731   0.0   7.07   0.0  0.469  ...     17.8  396.90   9.14    21.6     e
# 2  0.02729   0.0   7.07   0.0  0.469  ...     17.8  392.83   4.03    34.7     b
# 3  0.03237   0.0   2.18   0.0  0.458  ...     18.7  394.63   2.94    33.4     b
# 4  0.06905   0.0   2.18   0.0  0.458  ...     18.7  396.90   5.33    36.2     a
#
# [5 rows x 15 columns]

# %%
plt.figure(figsize = (10, 10))
sns.heatmap(df.corr(), annot = True)

# %%
sns.lmplot(data = df, x = 'target', y = 'lstat')

# %%
sns.lmplot(data = df, x = 'target', y = 'rm')

# %%
sns.lmplot(data = df, x = 'b', y = 'crim')

# %%
sns.lmplot(data = df, x = 'b', y = 'age')

# %%
print(raw['DESCR'])
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %% [markdown]
# # Iterators

# %%
users = [{'mail': 'gregorythomas@gmail.com', 'name': 'Brett Holland', 'sex': 'M', 'age': 73},
 {'mail': 'hintoncynthia@hotmail.com', 'name': 'Madison Martinez', 'sex': 'F', 'age': 29},
 {'mail': 'wwagner@gmail.com', 'name': 'Michael Jenkins', 'sex': 'M', 'age': 51},
 {'mail': 'daniel79@gmail.com', 'name': 'Karen Rodriguez', 'sex': 'F', 'age': 32},
 {'mail': 'ujackson@gmail.com', 'name': 'Amber Rhodes', 'sex': 'F', 'age': 42}]
users
# Out:
# [{'mail': 'gregorythomas@gmail.com',
#   'name': 'Brett Holland',
#   'sex': 'M',
#   'age': 73},
#  {'mail': 'hintoncynthia@hotmail.com',
#   'name': 'Madison Martinez',
#   'sex': 'F',
#   'age': 29},
#  {'mail': 'wwagner@gmail.com',
#   'name': 'Michael Jenkins',
#   'sex': 'M',
#   'age': 51},
#  {'mail': 'daniel79@gmail.com',
#   'name': 'Karen Rodriguez',
#   'sex': 'F',
#   'age': 32},
#  {'mail': 'ujackson@gmail.com', 'name': 'Amber Rhodes', 'sex': 'F', 'age': 42}]

# %%
{k : eval(f'reduce(lambda acc, cur : acc + [cur["{k}"]], users, [])') for k in list(users[0].keys())}
# Out:
# {'mail': ['gregorythomas@gmail.com',
#   'hintoncynthia@hotmail.com',
#   'wwagner@gmail.com',
#   'daniel79@gmail.com',
#   'ujackson@gmail.com'],
#  'name': ['Brett Holland',
#   'Madison Martinez',
#   'Michael Jenkins',
#   'Karen Rodriguez',
#   'Amber Rhodes'],
#  'sex': ['M', 'F', 'M', 'F', 'F'],
#  'age': [73, 29, 51, 32, 42]}
