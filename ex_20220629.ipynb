# %% [markdown]
# <a href="https://colab.research.google.com/github/aworklab/everydayPython/blob/main/ex_20220629.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 오늘의 목표
# * regressor
# * customer analysis

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotnine as gg
from plotnine import ggplot, aes
from datetime import datetime, date, time, timezone, timedelta
import os

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.impute import KNNImputer
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA 
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import roc_curve, roc_auc_score, f1_score, accuracy_score, mean_squared_error
import sklearn.datasets as skd

# %% [markdown]
# # regressor

# %%
raw = skd.load_boston()
x = pd.DataFrame(raw['data'], columns = raw['feature_names'])
y = raw['target']
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
#     Alternative datasets include the California housing dataset (i.e.
#     :func:`~sklearn.datasets.fetch_california_housing`) and the Ames housing
#     dataset. You can load the datasets as follows::
#
#         from sklearn.datasets import fetch_california_housing
#         housing = fetch_california_housing()
#
#     for the California housing dataset and::
#
#         from sklearn.datasets import fetch_openml
#         housing = fetch_openml(name="house_prices", as_frame=True)
#
#     for the Ames housing dataset.
#
#   warnings.warn(msg, category=FutureWarning)

# %%
x.columns = [a.lower() for a in x.columns]
x.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad    tax  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    ptratio       b  lstat
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
raw_ = pd.DataFrame(np.c_[x, y.reshape(-1,1)], columns = list(x.columns) + ['price'])
raw_.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad    tax  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    ptratio       b  lstat  price
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2

# %%
corr = raw_.corr()
corr.style.background_gradient(cmap = 'RdBu')
# Out:
# <style type="text/css">
# #T_306ec_row0_col0, #T_306ec_row1_col1, #T_306ec_row2_col2, #T_306ec_row3_col3, #T_306ec_row4_col4, #T_306ec_row5_col5, #T_306ec_row6_col6, #T_306ec_row7_col7, #T_306ec_row8_col8, #T_306ec_row9_col9, #T_306ec_row10_col10, #T_306ec_row11_col11, #T_306ec_row12_col12, #T_306ec_row13_col13 {
#   background-color: #053061;
#   color: #f1f1f1;
# }
# #T_306ec_row0_col1 {
#   background-color: #e17860;
#   color: #f1f1f1;
# }
# #T_306ec_row0_col2 {
#   background-color: #aed3e6;
#   color: #000000;
# }
# #T_306ec_row0_col3 {
#   background-color: #900d26;
#   color: #f1f1f1;
# }
# #T_306ec_row0_col4 {
#   background-color: #a2cde3;
#   color: #000000;
# }
# #T_306ec_row0_col5 {
#   background-color: #e37e64;
#   color: #f1f1f1;
# }
# #T_306ec_row0_col6, #T_306ec_row1_col13 {
#   background-color: #bddbea;
#   color: #000000;
# }
# #T_306ec_row0_col7, #T_306ec_row11_col4, #T_306ec_row11_col10 {
#   background-color: #dc6e57;
#   color: #f1f1f1;
# }
# #T_306ec_row0_col8 {
#   background-color: #6bacd1;
#   color: #f1f1f1;
# }
# #T_306ec_row0_col9, #T_306ec_row2_col8, #T_306ec_row8_col0 {
#   background-color: #7bb6d6;
#   color: #000000;
# }
# #T_306ec_row0_col10 {
#   background-color: #ecf2f5;
#   color: #000000;
# }
# #T_306ec_row0_col11, #T_306ec_row13_col9 {
#   background-color: #840924;
#   color: #f1f1f1;
# }
# #T_306ec_row0_col12 {
#   background-color: #9bc9e0;
#   color: #000000;
# }
# #T_306ec_row0_col13, #T_306ec_row9_col5 {
#   background-color: #d6604d;
#   color: #f1f1f1;
# }
# #T_306ec_row1_col0 {
#   background-color: #be3036;
#   color: #f1f1f1;
# }
# #T_306ec_row1_col2, #T_306ec_row1_col6, #T_306ec_row8_col3 {
#   background-color: #b3192c;
#   color: #f1f1f1;
# }
# #T_306ec_row1_col3 {
#   background-color: #991027;
#   color: #f1f1f1;
# }
# #T_306ec_row1_col4, #T_306ec_row1_col9 {
#   background-color: #c13639;
#   color: #f1f1f1;
# }
# #T_306ec_row1_col5, #T_306ec_row2_col0 {
#   background-color: #dbeaf2;
#   color: #000000;
# }
# #T_306ec_row1_col7, #T_306ec_row9_col4, #T_306ec_row13_col5 {
#   background-color: #3f8ec0;
#   color: #f1f1f1;
# }
# #T_306ec_row1_col8, #T_306ec_row5_col0 {
#   background-color: #ba2832;
#   color: #f1f1f1;
# }
# #T_306ec_row1_col10, #T_306ec_row9_col3, #T_306ec_row13_col8 {
#   background-color: #9f1228;
#   color: #f1f1f1;
# }
# #T_306ec_row1_col11 {
#   background-color: #fbe3d4;
#   color: #000000;
# }
# #T_306ec_row1_col12, #T_306ec_row5_col2, #T_306ec_row6_col3, #T_306ec_row10_col11 {
#   background-color: #d05548;
#   color: #f1f1f1;
# }
# #T_306ec_row2_col1, #T_306ec_row7_col3 {
#   background-color: #760521;
#   color: #f1f1f1;
# }
# #T_306ec_row2_col3, #T_306ec_row8_col1 {
#   background-color: #c94741;
#   color: #f1f1f1;
# }
# #T_306ec_row2_col4 {
#   background-color: #2c75b4;
#   color: #f1f1f1;
# }
# #T_306ec_row2_col5, #T_306ec_row7_col12 {
#   background-color: #bf3338;
#   color: #f1f1f1;
# }
# #T_306ec_row2_col6 {
#   background-color: #4695c4;
#   color: #f1f1f1;
# }
# #T_306ec_row2_col7, #T_306ec_row4_col1, #T_306ec_row11_col8 {
#   background-color: #7f0823;
#   color: #f1f1f1;
# }
# #T_306ec_row2_col9 {
#   background-color: #3c8abe;
#   color: #f1f1f1;
# }
# #T_306ec_row2_col10, #T_306ec_row13_col1 {
#   background-color: #d4e6f1;
#   color: #000000;
# }
# #T_306ec_row2_col11, #T_306ec_row11_col9, #T_306ec_row12_col3 {
#   background-color: #930e26;
#   color: #f1f1f1;
# }
# #T_306ec_row2_col12, #T_306ec_row6_col12, #T_306ec_row12_col6 {
#   background-color: #59a1ca;
#   color: #f1f1f1;
# }
# #T_306ec_row2_col13 {
#   background-color: #c2383a;
#   color: #f1f1f1;
# }
# #T_306ec_row3_col0 {
#   background-color: #e27b62;
#   color: #f1f1f1;
# }
# #T_306ec_row3_col1 {
#   background-color: #f7b799;
#   color: #000000;
# }
# #T_306ec_row3_col2 {
#   background-color: #fae9df;
#   color: #000000;
# }
# #T_306ec_row3_col4 {
#   background-color: #f8f3f0;
#   color: #000000;
# }
# #T_306ec_row3_col5 {
#   background-color: #fbe5d8;
#   color: #000000;
# }
# #T_306ec_row3_col6 {
#   background-color: #f8f1ed;
#   color: #000000;
# }
# #T_306ec_row3_col7 {
#   background-color: #fbceb7;
#   color: #000000;
# }
# #T_306ec_row3_col8, #T_306ec_row3_col9 {
#   background-color: #f6b394;
#   color: #000000;
# }
# #T_306ec_row3_col10 {
#   background-color: #e6866a;
#   color: #f1f1f1;
# }
# #T_306ec_row3_col11 {
#   background-color: #f8bb9e;
#   color: #000000;
# }
# #T_306ec_row3_col12 {
#   background-color: #fcd7c2;
#   color: #000000;
# }
# #T_306ec_row3_col13 {
#   background-color: #edf2f5;
#   color: #000000;
# }
# #T_306ec_row4_col0, #T_306ec_row12_col10 {
#   background-color: #d7e8f1;
#   color: #000000;
# }
# #T_306ec_row4_col2 {
#   background-color: #2e77b5;
#   color: #f1f1f1;
# }
# #T_306ec_row4_col3, #T_306ec_row5_col3, #T_306ec_row5_col8 {
#   background-color: #d25849;
#   color: #f1f1f1;
# }
# #T_306ec_row4_col5, #T_306ec_row13_col4 {
#   background-color: #d35a4a;
#   color: #f1f1f1;
# }
# #T_306ec_row4_col6 {
#   background-color: #337eb8;
#   color: #f1f1f1;
# }
# #T_306ec_row4_col7, #T_306ec_row6_col1, #T_306ec_row7_col2, #T_306ec_row7_col4, #T_306ec_row7_col6, #T_306ec_row7_col8, #T_306ec_row7_col9, #T_306ec_row8_col11, #T_306ec_row9_col11, #T_306ec_row10_col3, #T_306ec_row11_col0, #T_306ec_row12_col5, #T_306ec_row12_col13, #T_306ec_row13_col0, #T_306ec_row13_col10, #T_306ec_row13_col12 {
#   background-color: #67001f;
#   color: #f1f1f1;
# }
# #T_306ec_row4_col8 {
#   background-color: #71b0d3;
#   color: #f1f1f1;
# }
# #T_306ec_row4_col9 {
#   background-color: #4f9bc7;
#   color: #f1f1f1;
# }
# #T_306ec_row4_col10 {
#   background-color: #f9ede5;
#   color: #000000;
# }
# #T_306ec_row4_col11 {
#   background-color: #870a24;
#   color: #f1f1f1;
# }
# #T_306ec_row4_col12, #T_306ec_row8_col2 {
#   background-color: #5fa5cd;
#   color: #f1f1f1;
# }
# #T_306ec_row4_col13 {
#   background-color: #ce4f45;
#   color: #f1f1f1;
# }
# #T_306ec_row5_col1 {
#   background-color: #e0ecf3;
#   color: #000000;
# }
# #T_306ec_row5_col4, #T_306ec_row13_col3 {
#   background-color: #e98b6e;
#   color: #f1f1f1;
# }
# #T_306ec_row5_col6 {
#   background-color: #f19e7d;
#   color: #000000;
# }
# #T_306ec_row5_col7 {
#   background-color: #e3edf3;
#   color: #000000;
# }
# #T_306ec_row5_col9, #T_306ec_row10_col5 {
#   background-color: #c6413e;
#   color: #f1f1f1;
# }
# #T_306ec_row5_col10, #T_306ec_row12_col1 {
#   background-color: #b1182b;
#   color: #f1f1f1;
# }
# #T_306ec_row5_col11 {
#   background-color: #fdd9c4;
#   color: #000000;
# }
# #T_306ec_row5_col12 {
#   background-color: #9c1127;
#   color: #f1f1f1;
# }
# #T_306ec_row5_col13 {
#   background-color: #3a87bd;
#   color: #f1f1f1;
# }
# #T_306ec_row6_col0 {
#   background-color: #eaf1f5;
#   color: #000000;
# }
# #T_306ec_row6_col2 {
#   background-color: #4997c5;
#   color: #f1f1f1;
# }
# #T_306ec_row6_col4 {
#   background-color: #327cb7;
#   color: #f1f1f1;
# }
# #T_306ec_row6_col5 {
#   background-color: #df765e;
#   color: #f1f1f1;
# }
# #T_306ec_row6_col7 {
#   background-color: #700320;
#   color: #f1f1f1;
# }
# #T_306ec_row6_col8 {
#   background-color: #bbdaea;
#   color: #000000;
# }
# #T_306ec_row6_col9 {
#   background-color: #a0cce2;
#   color: #000000;
# }
# #T_306ec_row6_col10, #T_306ec_row7_col11 {
#   background-color: #f3f5f6;
#   color: #000000;
# }
# #T_306ec_row6_col11 {
#   background-color: #b82531;
#   color: #f1f1f1;
# }
# #T_306ec_row6_col13 {
#   background-color: #d86551;
#   color: #f1f1f1;
# }
# #T_306ec_row7_col0 {
#   background-color: #6a011f;
#   color: #f1f1f1;
# }
# #T_306ec_row7_col1 {
#   background-color: #4c99c6;
#   color: #f1f1f1;
# }
# #T_306ec_row7_col5 {
#   background-color: #f5f6f7;
#   color: #000000;
# }
# #T_306ec_row7_col10 {
#   background-color: #cf5246;
#   color: #f1f1f1;
# }
# #T_306ec_row7_col13 {
#   background-color: #ddebf2;
#   color: #000000;
# }
# #T_306ec_row8_col4 {
#   background-color: #529dc8;
#   color: #f1f1f1;
# }
# #T_306ec_row8_col5 {
#   background-color: #e58368;
#   color: #f1f1f1;
# }
# #T_306ec_row8_col6 {
#   background-color: #98c8e0;
#   color: #000000;
# }
# #T_306ec_row8_col7, #T_306ec_row9_col13, #T_306ec_row12_col7 {
#   background-color: #c53e3d;
#   color: #f1f1f1;
# }
# #T_306ec_row8_col9 {
#   background-color: #144e8a;
#   color: #f1f1f1;
# }
# #T_306ec_row8_col10 {
#   background-color: #b3d6e8;
#   color: #000000;
# }
# #T_306ec_row8_col12 {
#   background-color: #8dc2dc;
#   color: #000000;
# }
# #T_306ec_row8_col13, #T_306ec_row11_col2 {
#   background-color: #d7634f;
#   color: #f1f1f1;
# }
# #T_306ec_row9_col0, #T_306ec_row12_col9 {
#   background-color: #90c4dd;
#   color: #000000;
# }
# #T_306ec_row9_col1 {
#   background-colo

# %%
from statsmodels.formula.api import ols

# %%
price_vs_rm = ols('price ~ rm', data = raw_ ).fit()
price_vs_rm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.484
# Model:                            OLS   Adj. R-squared:                  0.483
# Method:                 Least Squares   F-statistic:                     471.8
# Date:                Wed, 29 Jun 2022   Prob (F-statistic):           2.49e-74
# Time:                        00:26:10   Log-Likelihood:                -1673.1
# No. Observations:                 506   AIC:                             3350.
# Df Residuals:                     504   BIC:                             3359.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -34.6706      2.650    -13.084      0.000     -39.877     -29.465
# rm             9.1021      0.419     21.722      0.000       8.279       9.925
# ==============================================================================
# Omnibus:                      102.585   Durbin-Watson:                   0.684
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              612.449
# Skew:                           0.726   Prob(JB):                    1.02e-133
# Kurtosis:                       8.190   Cond. No.                         58.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
raw_.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'price'],
#       dtype='object')

# %%
mix_model = ols('price ~ crim + zn + indus + chas + nox + rm + age + dis + rad + tax + ptratio + b + lstat', data = raw_).fit()
mix_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.741
# Model:                            OLS   Adj. R-squared:                  0.734
# Method:                 Least Squares   F-statistic:                     108.1
# Date:                Wed, 29 Jun 2022   Prob (F-statistic):          6.72e-135
# Time:                        00:31:01   Log-Likelihood:                -1498.8
# No. Observations:                 506   AIC:                             3026.
# Df Residuals:                     492   BIC:                             3085.
# Df Model:                          13
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     36.4595      5.103      7.144      0.000      26.432      46.487
# crim          -0.1080      0.033     -3.287      0.001      -0.173      -0.043
# zn             0.0464      0.014      3.382      0.001       0.019       0.073
# indus          0.0206      0.061      0.334      0.738      -0.100       0.141
# chas           2.6867      0.862      3.118      0.002       0.994       4.380
# nox          -17.7666      3.820     -4.651      0.000     -25.272     -10.262
# rm             3.8099      0.418      9.116      0.000       2.989       4.631
# age            0.0007      0.013      0.052      0.958      -0.025       0.027
# dis           -1.4756      0.199     -7.398      0.000      -1.867      -1.084
# rad            0.3060      0.066      4.613      0.000       0.176       0.436
# tax           -0.0123      0.004     -3.280      0.001      -0.020      -0.005
# ptratio       -0.9527      0.131     -7.283      0.000      -1.210      -0.696
# b              0.0093      0.003      3.467      0.001       0.004       0.015
# lstat         -0.5248      0.051    -10.347      0.000      -0.624      -0.425
# ==============================================================================
# Omnibus:                      178.041   Durbin-Watson:                   1.078
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              783.126
# Skew:                           1.521   Prob(JB):                    8.84e-171
# Kurtosis:                       8.281   Cond. No.                     1.51e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.51e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
x_tr, x_te, y_tr, y_te = train_test_split(x, y, train_size = .7)

# %%
scaler = RobustScaler()
x_tr_std = scaler.fit_transform(x_tr)
x_te_std = scaler.transform(x_te)

# %%
fit_lm = LinearRegression().fit(x_tr, y_tr)
fit_lm_std = LinearRegression().fit(x_tr_std, y_tr)
fit_rf = RandomForestRegressor().fit(x_tr, y_tr)

# %%
pred_lm = fit_lm.predict(x_te)
pred_lm_std = fit_lm.predict(x_te_std)
pred_rf = fit_rf.predict(x_te)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"

# %%
mean_squared_error(y_te, pred_lm), mean_squared_error(y_te, pred_lm_std), mean_squared_error(y_te, pred_rf)
# Out:
# (24.790465605657143, 411.8861654146121, 9.729617592105267)

# %%
plt.figure(figsize = [6,6])
plt.plot([0, 50], [0, 50], 'gray')
plt.plot(y_te, pred_lm, '.', color = 'red')
plt.plot(y_te, pred_lm_std, '.', color = 'orange')
plt.plot(y_te, pred_rf, '.', color = 'green')

# %% [markdown]
# # customer analysis

# %%
os.listdir()
# Out:
# ['.config',
#  'retail_data_response.csv',
#  'online_retail_II.xlsx',
#  'ecommerce-data.csv',
#  'rfm_test.csv',
#  '.Rhistory',
#  'sample_submission.csv',
#  'shops.csv',
#  'items.csv',
#  'item_categories.csv',
#  'sales_train.csv',
#  'KPMG_VI_New_raw_data_update_final.xlsx',
#  'retail_data_transactions.csv',
#  'test.csv',
#  'sample_data']

# %%
df = pd.read_csv('retail_data_transactions.csv')
df.head()
# Out:
#   customer_id trans_date  tran_amount
# 0      CS5295  11-Feb-13           35
# 1      CS4768  15-Mar-15           39
# 2      CS2122  26-Feb-13           52
# 3      CS1217  16-Nov-11           99
# 4      CS1850  20-Nov-13           78

# %%
df.columns = ['id', 'date', 'rev']
df['date'] = pd.to_datetime(df['date'])
df.head()
# Out:
#        id       date  rev
# 0  CS5295 2013-02-11   35
# 1  CS4768 2015-03-15   39
# 2  CS2122 2013-02-26   52
# 3  CS1217 2011-11-16   99
# 4  CS1850 2013-11-20   78

# %%
df['month'] = df['date'].to_numpy().astype('datetime64[M]')
df.head()
# Out:
#        id       date  rev      month
# 0  CS5295 2013-02-11   35 2013-02-01
# 1  CS4768 2015-03-15   39 2015-03-01
# 2  CS2122 2013-02-26   52 2013-02-01
# 3  CS1217 2011-11-16   99 2011-11-01
# 4  CS1850 2013-11-20   78 2013-11-01

# %%
df = df.groupby(['id', 'month', 'date'])['rev'].sum().reset_index()
df.head()
# Out:
#        id      month       date  rev
# 0  CS1112 2011-06-01 2011-06-15   56
# 1  CS1112 2011-08-01 2011-08-19   96
# 2  CS1112 2011-10-01 2011-10-02   60
# 3  CS1112 2012-04-01 2012-04-08   56
# 4  CS1112 2012-06-01 2012-06-24   52

# %%
info_m = df.groupby(['id', 'month'])['rev'].sum().reset_index().rename(columns = {'rev':'money'})
info_m = pd.pivot_table(info_m, index = 'id', columns = 'month', values = 'money').reset_index()
info_m = pd.melt(info_m, id_vars = 'id', var_name = 'month', value_name = 'money').sort_values(['id', 'month'], ascending = [1,0])
info_m = info_m.groupby(['id']).head(3)
info_m = info_m.groupby(['id'])['money'].sum().reset_index()
info_m.head()
# Out:
#        id  money
# 0  CS1112   39.0
# 1  CS1113  220.0
# 2  CS1114   79.0
# 3  CS1115   55.0
# 4  CS1116    0.0

# %%
info_f = df.groupby(['id', 'month'])['rev'].count().reset_index().rename(columns = {'rev':'freq'})
info_f = pd.pivot_table(info_f, index = 'id', columns = 'month', values = 'freq').reset_index()
info_f = pd.melt(info_f, id_vars = 'id', var_name = 'month', value_name = 'freq').sort_values(['id', 'month'], ascending = [1,0])
info_f = info_f.groupby(['id']).head(3)
info_f = info_f.groupby(['id'])['freq'].sum().reset_index()
info_f.head()
# Out:
#        id  freq
# 0  CS1112   1.0
# 1  CS1113   2.0
# 2  CS1114   1.0
# 3  CS1115   1.0
# 4  CS1116   0.0

# %%
df['date'].max()
# Out:
# Timestamp('2015-03-16 00:00:00')

# %%
date_now = datetime(2015,4,1)

# %%
info_r = df.groupby('id').agg({'date' : lambda x : (date_now - x.max()).days}).reset_index().rename(columns = {'date':'recency'})
info_r.head()
# Out:
#        id  recency
# 0  CS1112       77
# 1  CS1113       51
# 2  CS1114       48
# 3  CS1115       27
# 4  CS1116      219

# %%
info = pd.merge(pd.merge(info_r, info_f, 'left', 'id'), info_m, 'left', 'id')
info.head()
# Out:
#        id  recency  freq  money
# 0  CS1112       77   1.0   39.0
# 1  CS1113       51   2.0  220.0
# 2  CS1114       48   1.0   79.0
# 3  CS1115       27   1.0   55.0
# 4  CS1116      219   0.0    0.0

# %%
info = info.assign(r = pd.qcut(info['recency'], 5, list('12345')),
            f = pd.qcut(info['freq'].rank(method = 'first'), 5, list('54321')),
            m = pd.qcut(info['money'].rank(method = 'first'), 5, list('54321'))
            )
info.head()
# Out:
#        id  recency  freq  money  r  f  m
# 0  CS1112       77   1.0   39.0  3  4  3
# 1  CS1113       51   2.0  220.0  2  2  1
# 2  CS1114       48   1.0   79.0  2  4  2
# 3  CS1115       27   1.0   55.0  1  4  3
# 4  CS1116      219   0.0    0.0  5  5  5

# %%
info = info.assign(rf = info['r'].astype(str) + info['f'].astype(str))
info.head()
# Out:
#        id  recency  freq  money  r  f  m  rf
# 0  CS1112       77   1.0   39.0  3  4  3  34
# 1  CS1113       51   2.0  220.0  2  2  1  22
# 2  CS1114       48   1.0   79.0  2  4  2  24
# 3  CS1115       27   1.0   55.0  1  4  3  14
# 4  CS1116      219   0.0    0.0  5  5  5  55

# %%
seg_map = {
    r'[1-2][1-2]': 'hibernating',
    r'[1-2][3-4]': 'at_Risk',
    r'[1-2]5': 'cant_loose',
    r'3[1-2]': 'about_to_sleep',
    r'33': 'need_attention',
    r'[3-4][4-5]': 'loyal_customers',
    r'41': 'promising',
    r'51': 'new_customers',
    r'[4-5][2-3]': 'potential_loyalists',
    r'5[4-5]': 'champions'
}

# %%
info.assign(rf = info['rf'].replace(seg_map, regex = True))
# Out:
#           id  recency  freq  money  r  f  m               rf
# 0     CS1112       77   1.0   39.0  3  4  3  loyal_customers
# 1     CS1113       51   2.0  220.0  2  2  1      hibernating
# 2     CS1114       48   1.0   79.0  2  4  2          at_Risk
# 3     CS1115       27   1.0   55.0  1  4  3          at_Risk
# 4     CS1116      219   0.0    0.0  5  5  5        champions
# ...      ...      ...   ...    ... .. .. ..              ...
# 6884  CS8996      113   0.0    0.0  4  4  4  loyal_customers
# 6885  CS8997      277   0.0    0.0  5  4  4        champions
# 6886  CS8998      100   0.0    0.0  4  4  4  loyal_customers
# 6887  CS8999      273   0.0    0.0  5  4  4        champions
# 6888  CS9000       32   1.0   34.0  1  2  3      hibernating
#
# [6889 rows x 8 columns]
