# %% [markdown]
# <a href="https://colab.research.google.com/github/aworklab/everydayPython/blob/main/ex_20230530.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 오늘의 목표
# * Customer Analysis
# * Iterators

# %%
import pandas as pd
import numpy as np
import plotnine as gg
from plotnine import ggplot, aes
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, date, time, timezone, timedelta 
import os
import re
from functools import reduce
from collections import defaultdict
from scipy import stats
from scipy.stats import norm

# %% [markdown]
# # Customer Analysis

# %%
os.listdir()
# Out:
# ['.config',
#  'mall_customers.csv',
#  'match_result_test.csv',
#  'cookie_cats.csv',
#  'sales_vs_discount.csv',
#  'ab_experiment.csv',
#  'ecommerce-data.csv',
#  'scanner_data.csv',
#  'groceries.csv',
#  'test.csv',
#  'KPMG_VI_New_raw_data_update_final.csv',
#  'sample-sales-data.csv',
#  'KPMG_VI_New_raw_data_update_final.xlsx',
#  'sales.csv',
#  'sales_data_with_stores.csv',
#  'lead_conversion.csv',
#  'app_wau.csv',
#  '1_customers_dataset.csv',
#  'online_retail_II.xlsx',
#  'bz_data_analyis.csv',
#  'WA_Fn-UseC_-Marketing-Customer-Value-Analysis.csv',
#  '1_orders_dataset.csv',
#  'online_retail.xlsx',
#  'mock_sales_data.csv',
#  '1_order_payments_dataset.csv',
#  'WA_Fn-UseC_-Telco-Customer-Churn.csv',
#  'sample_data']

# %%
df = pd.read_csv('bz_data_analyis.csv')
df['order_date'] = pd.to_datetime(df['order_date'], format = '%m/%d/%y %H:%M')
df['date'] = df['order_date'].to_numpy().astype('datetime64[D]')
df['week'] = df['date'] - df['date'].dt.weekday.astype('timedelta64[D]')
df['weekday'] = df['date'].dt.weekday
df['month'] = df['date'].dt.month
df.head()
# Out:
# <ipython-input-21-46b26744190d>:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#    customer_id               product  ...       week  weekday
# 0       295665    Macbook Pro Laptop  ... 2019-12-30        0
# 1       295666    LG Washing Machine  ... 2019-12-23        6
# 2       295667  USB-C Charging Cable  ... 2019-12-09        3
# 3       295668      27in FHD Monitor  ... 2019-12-16        6
# 4       295669  USB-C Charging Cable  ... 2019-12-16        2
#
# [5 rows x 18 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185950 entries, 0 to 185949
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   customer_id       185950 non-null  int64
#  1   product           185950 non-null  object
#  2   quantity_ordered  185950 non-null  object
#  3   price_each        185950 non-null  float64
#  4   purchase_address  185950 non-null  object
#  5   month             185950 non-null  int64
#  6   year              185950 non-null  int64
#  7   day               185950 non-null  int64
#  8   city              185950 non-null  object
#  9   code              185950 non-null  object
#  10  sales             185950 non-null  float64
#  11  order_date        185950 non-null  datetime64[ns]
#  12  hour              185950 non-null  int64
#  13  minute            185950 non-null  int64
#  14  count             185950 non-null  int64
# ...

# %%
df['quantity_ordered'] = df['quantity_ordered'].astype(str)

# %%
df = df[~df['quantity_ordered'].str.contains('[a-zA-Z]')]

# %%
df['quantity_ordered'] = df['quantity_ordered'].astype(int)

# %%
df['rev'] = df['quantity_ordered'] * df['price_each']
df.head()
# Out:
#    customer_id               product  ...  weekday      rev
# 0       295665    Macbook Pro Laptop  ...        0  1700.00
# 1       295666    LG Washing Machine  ...        6  1800.00
# 2       295667  USB-C Charging Cable  ...        3    35.85
# 3       295668      27in FHD Monitor  ...        6   299.98
# 4       295669  USB-C Charging Cable  ...        2    11.95
#
# [5 rows x 19 columns]

# %%
df['weekday'] = df['date'].dt.weekday
list_weekday = dict(zip(range(7), ['mon', 'tue', 'wed', 'thu', 'fri', 'sat', 'sun']))
df['weekday'] = df['weekday'].apply(lambda x : list_weekday.get(x,x))
df['weekday'] = pd.Categorical(df['weekday2'], categories = list_weekday.values())
df.head()
# Out:
#    customer_id               product  ...      rev  weekday2
# 0       295665    Macbook Pro Laptop  ...  1700.00       mon
# 1       295666    LG Washing Machine  ...  1800.00       sun
# 2       295667  USB-C Charging Cable  ...    35.85       thu
# 3       295668      27in FHD Monitor  ...   299.98       sun
# 4       295669  USB-C Charging Cable  ...    11.95       wed
#
# [5 rows x 20 columns]

# %%
con_q = df.groupby(['month','weekday'])['rev'].quantile([.25, .5, .75, .95]).reset_index().rename(columns = {'level_2':'q'})
con_q.head()
# Out:
#    month weekday     q     rev
# 0      1     mon  0.25   11.95
# 1      1     mon  0.50   14.95
# 2      1     mon  0.75  150.00
# 3      1     mon  0.95  700.00
# 4      1     tue  0.25   11.95

# %%
g = sns.FacetGrid(con_q, col = 'month', col_wrap = 6, hue = 'q')
g.map(sns.lineplot, 'weekday', 'rev')
g.add_legend()
plt.show()

# %%
df[df['rev'] >= 600]
# Out:
#         customer_id             product  ...      rev  weekday2
# 0            295665  Macbook Pro Laptop  ...  1700.00       mon
# 1            295666  LG Washing Machine  ...  1800.00       sun
# 11           295676     ThinkPad Laptop  ...   999.99       sat
# 16           295681        Google Phone  ...   600.00       wed
# 27           295689  LG Washing Machine  ...   600.00       tue
# ...             ...                 ...  ...      ...       ...
# 185913       222876  LG Washing Machine  ...   600.00       sat
# 185922       222884        Google Phone  ...   600.00       tue
# 185924       222885            LG Dryer  ...   600.00       sat
# 185942       222903              iPhone  ...   700.00       fri
# 185944       222904  Macbook Pro Laptop  ...  1700.00       sun
#
# [22590 rows x 20 columns]

# %%
con_q2 = pd.pivot_table(con_q, index = ['month','weekday'], columns = 'q', values = 'rev').reset_index()
con_q2.head()
# Out:
# q  month weekday   0.25    0.5   0.75    0.95
# 0      1     mon  11.95  14.95  150.0  700.00
# 1      1     tue  11.95  14.95  150.0  999.99
# 2      1     wed  11.95  15.36  150.0  700.00
# 3      1     thu  11.95  14.95  150.0  700.00
# 4      1     fri  11.95  14.95  150.0  999.99

# %%
con_q2.groupby(['month', 'weekday'])[[0.25, 0.5, 0.75, 0.95]].apply(lambda x: x.reset_index(drop=True).to_dict())
# Out:
# month  weekday
# 1      mon        {0.25: {0: 11.95}, 0.5: {0: 14.95}, 0.75: {0: ...
#        tue        {0.25: {0: 11.95}, 0.5: {0: 14.95}, 0.75: {0: ...
#        wed        {0.25: {0: 11.95}, 0.5: {0: 15.36}, 0.75: {0: ...
#        thu        {0.25: {0: 11.95}, 0.5: {0: 14.95}, 0.75: {0: ...
#        fri        {0.25: {0: 11.95}, 0.5: {0: 14.95}, 0.75: {0: ...
#                                         ...
# 12     wed        {0.25: {0: 11.95}, 0.5: {0: 14.95}, 0.75: {0: ...
#        thu        {0.25: {0: 11.95}, 0.5: {0: 14.95}, 0.75: {0: ...
#        fri        {0.25: {0: 11.95}, 0.5: {0: 14.95}, 0.75: {0: ...
#        sat        {0.25: {0: 11.95}, 0.5: {0: 14.95}, 0.75: {0: ...
#        sun        {0.25: {0: 11.95}, 0.5: {0: 14.95}, 0.75: {0: ...
# Length: 84, dtype: object

# %%
df2 = pd.merge(df, con_q2, 'left', ['month','weekday'])
df2.head()
# Out:
#    customer_id               product  quantity_ordered  ...    0.5   0.75   0.95
# 0       295665    Macbook Pro Laptop                 1  ...  14.95  150.0  700.0
# 1       295666    LG Washing Machine                 3  ...  14.95  150.0  700.0
# 2       295667  USB-C Charging Cable                 3  ...  14.95  150.0  700.0
# 3       295668      27in FHD Monitor                 2  ...  14.95  150.0  700.0
# 4       295669  USB-C Charging Cable                 1  ...  14.95  150.0  700.0
#
# [5 rows x 24 columns]

# %% [markdown]
# # Iterators

# %%
users = [{'mail': 'gregorythomas@gmail.com', 'name': 'Brett Holland', 'sex': 'M', 'age': 73},
 {'mail': 'hintoncynthia@hotmail.com', 'name': 'Madison Martinez', 'sex': 'F', 'age': 29},
 {'mail': 'wwagner@gmail.com', 'name': 'Michael Jenkins', 'sex': 'M', 'age': 51},
 {'mail': 'daniel79@gmail.com', 'name': 'Karen Rodriguez', 'sex': 'F', 'age': 32},
 {'mail': 'ujackson@gmail.com', 'name': 'Amber Rhodes', 'sex': 'F', 'age': 42}]
users
# Out:
# [{'mail': 'gregorythomas@gmail.com',
#   'name': 'Brett Holland',
#   'sex': 'M',
#   'age': 73},
#  {'mail': 'hintoncynthia@hotmail.com',
#   'name': 'Madison Martinez',
#   'sex': 'F',
#   'age': 29},
#  {'mail': 'wwagner@gmail.com',
#   'name': 'Michael Jenkins',
#   'sex': 'M',
#   'age': 51},
#  {'mail': 'daniel79@gmail.com',
#   'name': 'Karen Rodriguez',
#   'sex': 'F',
#   'age': 32},
#  {'mail': 'ujackson@gmail.com', 'name': 'Amber Rhodes', 'sex': 'F', 'age': 42}]

# %%
{k : eval(f'reduce(lambda acc, cur : acc + [cur["{k}"]], users, [])') for k in users[0].keys()}
# Out:
# {'mail': ['gregorythomas@gmail.com',
#   'hintoncynthia@hotmail.com',
#   'wwagner@gmail.com',
#   'daniel79@gmail.com',
#   'ujackson@gmail.com'],
#  'name': ['Brett Holland',
#   'Madison Martinez',
#   'Michael Jenkins',
#   'Karen Rodriguez',
#   'Amber Rhodes'],
#  'sex': ['M', 'F', 'M', 'F', 'F'],
#  'age': [73, 29, 51, 32, 42]}

# %%
{k : [user[k] for user in users] for k in users[0].keys()}
# Out:
# {'mail': ['gregorythomas@gmail.com',
#   'hintoncynthia@hotmail.com',
#   'wwagner@gmail.com',
#   'daniel79@gmail.com',
#   'ujackson@gmail.com'],
#  'name': ['Brett Holland',
#   'Madison Martinez',
#   'Michael Jenkins',
#   'Karen Rodriguez',
#   'Amber Rhodes'],
#  'sex': ['M', 'F', 'M', 'F', 'F'],
#  'age': [73, 29, 51, 32, 42]}
