# %% [markdown]
# <a href="https://colab.research.google.com/github/aworklab/everydayPython/blob/main/ex_20230428.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 오늘의 목표
# * Customer Analysis
# * Iterators

# %%
import pandas as pd
import numpy as np
import plotnine as gg
from plotnine import ggplot, aes
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, date, time, timezone, timedelta
import os
import re
from functools import reduce
from collections import defaultdict
from scipy import stats
from scipy.stats import norm

# %% [markdown]
# # Customer Analysis

# %%
os.listdir()
# Out:
# ['.config',
#  'sales_data_with_stores.csv',
#  'test.csv',
#  'KPMG_VI_New_raw_data_update_final.xlsx',
#  'app_wau.csv',
#  '1_orders_dataset.csv',
#  'sales.csv',
#  'cookie_cats.csv',
#  'KPMG_VI_New_raw_data_update_final.csv',
#  'online_retail_II.xlsx',
#  '1_customers_dataset.csv',
#  'sample-sales-data.csv',
#  '1_order_payments_dataset.csv',
#  'online_retail.xlsx',
#  'ecommerce-data.csv',
#  'bz_data_analyis.csv',
#  'scanner_data.csv',
#  'WA_Fn-UseC_-Telco-Customer-Churn.csv',
#  'WA_Fn-UseC_-Marketing-Customer-Value-Analysis.csv',
#  'groceries.csv',
#  'mock_sales_data.csv',
#  'match_result_test.csv',
#  'mall_customers.csv',
#  'lead_conversion.csv',
#  'sales_vs_discount.csv',
#  'ab_experiment.csv',
#  'sample_data']

# %%
df = pd.read_csv('WA_Fn-UseC_-Marketing-Customer-Value-Analysis.csv')
df.columns = [re.sub(' ','_', a).lower() for a in df.columns]
df['effective_to_date'] = pd.to_datetime(df['effective_to_date'], format = '%m/%d/%y')
df['week'] = df['effective_to_date'] - df['effective_to_date'].dt.week.astype('timedelta64[D]')
df = df.rename(columns = {'customer_lifetime_value':'ltv'})
df.head()
# Out:
# <ipython-input-8-695877cd723b>:4: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   customer       state           ltv  ...  vehicle_class vehicle_size       week
# 0  BU79786  Washington   2763.519279  ...   Two-Door Car      Medsize 2011-02-16
# 1  QZ44356     Arizona   6979.535903  ...  Four-Door Car      Medsize 2011-01-26
# 2  AI49188      Nevada  12887.431650  ...   Two-Door Car      Medsize 2011-02-12
# 3  WW63253  California   7645.861827  ...            SUV      Medsize 2011-01-17
# 4  HB64268  Washington   2813.692575  ...  Four-Door Car      Medsize 2011-01-29
#
# [5 rows x 25 columns]

# %%
sns.histplot(data = df, x = 'income', hue = 'gender', kde = True, bins = 35)
plt.show()

# %%
sns.histplot(data = df, x = 'ltv', hue = 'gender', kde = True, bins = 35)
plt.show()

# %%
sns.lmplot(data = df, x = 'ltv', y = 'income', hue ='gender', scatter_kws = {'alpha':0.1})
plt.show()

# %%
sns.lmplot(data = df, x = 'total_claim_amount', y = 'ltv', hue ='gender', scatter_kws = {'alpha':0.1})
plt.show()

# %% [markdown]
# # Iterators

# %%
users = [{'mail': 'gregorythomas@gmail.com', 'name': 'Brett Holland', 'sex': 'M', 'age': 73},
 {'mail': 'hintoncynthia@hotmail.com', 'name': 'Madison Martinez', 'sex': 'F', 'age': 29},
 {'mail': 'wwagner@gmail.com', 'name': 'Michael Jenkins', 'sex': 'M', 'age': 51},
 {'mail': 'daniel79@gmail.com', 'name': 'Karen Rodriguez', 'sex': 'F', 'age': 32},
 {'mail': 'ujackson@gmail.com', 'name': 'Amber Rhodes', 'sex': 'F', 'age': 42}]
users
# Out:
# [{'mail': 'gregorythomas@gmail.com',
#   'name': 'Brett Holland',
#   'sex': 'M',
#   'age': 73},
#  {'mail': 'hintoncynthia@hotmail.com',
#   'name': 'Madison Martinez',
#   'sex': 'F',
#   'age': 29},
#  {'mail': 'wwagner@gmail.com',
#   'name': 'Michael Jenkins',
#   'sex': 'M',
#   'age': 51},
#  {'mail': 'daniel79@gmail.com',
#   'name': 'Karen Rodriguez',
#   'sex': 'F',
#   'age': 32},
#  {'mail': 'ujackson@gmail.com', 'name': 'Amber Rhodes', 'sex': 'F', 'age': 42}]

# %%
{k : eval(f'reduce(lambda acc, cur : acc + [cur["{k}"]], users, [])') for k in users[0].keys()}
# Out:
# {'mail': ['gregorythomas@gmail.com',
#   'hintoncynthia@hotmail.com',
#   'wwagner@gmail.com',
#   'daniel79@gmail.com',
#   'ujackson@gmail.com'],
#  'name': ['Brett Holland',
#   'Madison Martinez',
#   'Michael Jenkins',
#   'Karen Rodriguez',
#   'Amber Rhodes'],
#  'sex': ['M', 'F', 'M', 'F', 'F'],
#  'age': [73, 29, 51, 32, 42]}

# %%
{k : [user[k] for user in users] for k in users[0].keys()}
# Out:
# {'mail': ['gregorythomas@gmail.com',
#   'hintoncynthia@hotmail.com',
#   'wwagner@gmail.com',
#   'daniel79@gmail.com',
#   'ujackson@gmail.com'],
#  'name': ['Brett Holland',
#   'Madison Martinez',
#   'Michael Jenkins',
#   'Karen Rodriguez',
#   'Amber Rhodes'],
#  'sex': ['M', 'F', 'M', 'F', 'F'],
#  'age': [73, 29, 51, 32, 42]}
