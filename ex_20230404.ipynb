# %% [markdown]
# <a href="https://colab.research.google.com/github/aworklab/everydayPython/blob/main/ex_20230404.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 오늘의 목표
# * Customer Analysis
# * Iterators

# %%
import pandas as pd
import numpy as np
import plotnine as gg
from plotnine import ggplot, aes
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, date, time, timezone, timedelta
import os 
import re
from functools import reduce
from collections import defaultdict
from scipy import stats
from scipy.stats import norm

# %% [markdown]
# # Customer Analysis

# %%
os.listdir()
# Out:
# ['.config',
#  'app_wau.csv',
#  'cookie_cats.csv',
#  'online_retail_II.xlsx',
#  'lead_conversion.csv',
#  'test.csv',
#  'bz_data_analyis.csv',
#  'sales_data_with_stores.csv',
#  'mall_customers.csv',
#  'mock_sales_data.csv',
#  'groceries.csv',
#  'WA_Fn-UseC_-Marketing-Customer-Value-Analysis.csv',
#  'online_retail.xlsx',
#  '1_orders_dataset.csv',
#  '1_order_payments_dataset.csv',
#  'scanner_data.csv',
#  'KPMG_VI_New_raw_data_update_final.xlsx',
#  'KPMG_VI_New_raw_data_update_final.csv',
#  'ab_experiment.csv',
#  'sales.csv',
#  'ecommerce-data.csv',
#  'sales_vs_discount.csv',
#  'sample-sales-data.csv',
#  '1_customers_dataset.csv',
#  'match_result_test.csv',
#  'WA_Fn-UseC_-Telco-Customer-Churn.csv',
#  'sample_data']

# %%
df = pd.read_csv('mall_customers.csv')
df.columns = ['_'.join(re.split('(?=[A-Z][a-z])', re.sub('\(.+\)| ', '', a))).lower().lstrip('_') for a in df.columns]
df.head()
# Out:
#    customerid  gender  age  annual_income  spending_score
# 0           1    Male   19             15              39
# 1           2    Male   21             15              81
# 2           3  Female   20             16               6
# 3           4  Female   23             16              77
# 4           5  Female   31             17              40

# %%
sns.set(rc = {'figure.figsize':[12,6]})
sns.countplot(data = df, x = 'gender')
plt.show()

# %%
sns.heatmap(df.corr(),annot = True)
# Out:
# <Axes: >

# %%
sns.lmplot(data = df, x = 'spending_score', y = 'annual_income', hue = 'gender')
plt.show()

# %% [markdown]
# # Iterators

# %%
users = [{'mail': 'gregorythomas@gmail.com', 'name': 'Brett Holland', 'sex': 'M', 'age': 73},
 {'mail': 'hintoncynthia@hotmail.com', 'name': 'Madison Martinez', 'sex': 'F', 'age': 29},
 {'mail': 'wwagner@gmail.com', 'name': 'Michael Jenkins', 'sex': 'M', 'age': 51},
 {'mail': 'daniel79@gmail.com', 'name': 'Karen Rodriguez', 'sex': 'F', 'age': 32},
 {'mail': 'ujackson@gmail.com', 'name': 'Amber Rhodes', 'sex': 'F', 'age': 42}]
users
# Out:
# [{'mail': 'gregorythomas@gmail.com',
#   'name': 'Brett Holland',
#   'sex': 'M',
#   'age': 73},
#  {'mail': 'hintoncynthia@hotmail.com',
#   'name': 'Madison Martinez',
#   'sex': 'F',
#   'age': 29},
#  {'mail': 'wwagner@gmail.com',
#   'name': 'Michael Jenkins',
#   'sex': 'M',
#   'age': 51},
#  {'mail': 'daniel79@gmail.com',
#   'name': 'Karen Rodriguez',
#   'sex': 'F',
#   'age': 32},
#  {'mail': 'ujackson@gmail.com', 'name': 'Amber Rhodes', 'sex': 'F', 'age': 42}]

# %%
{k : eval(f'reduce(lambda acc, cur : acc + [cur["{k}"]], users, [])') for k in users[0].keys()}
# Out:
# {'mail': ['gregorythomas@gmail.com',
#   'hintoncynthia@hotmail.com',
#   'wwagner@gmail.com',
#   'daniel79@gmail.com',
#   'ujackson@gmail.com'],
#  'name': ['Brett Holland',
#   'Madison Martinez',
#   'Michael Jenkins',
#   'Karen Rodriguez',
#   'Amber Rhodes'],
#  'sex': ['M', 'F', 'M', 'F', 'F'],
#  'age': [73, 29, 51, 32, 42]}

# %%
{k : [user[k] for user in users] for k in users[0].keys()}
# Out:
# {'mail': ['gregorythomas@gmail.com',
#   'hintoncynthia@hotmail.com',
#   'wwagner@gmail.com',
#   'daniel79@gmail.com',
#   'ujackson@gmail.com'],
#  'name': ['Brett Holland',
#   'Madison Martinez',
#   'Michael Jenkins',
#   'Karen Rodriguez',
#   'Amber Rhodes'],
#  'sex': ['M', 'F', 'M', 'F', 'F'],
#  'age': [73, 29, 51, 32, 42]}
